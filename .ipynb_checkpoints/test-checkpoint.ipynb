# %%
import FEMSections as FEM
import FEMSections.FEM2D.Mesh as Mesh
import numpy as np
import matplotlib.pyplot as plt
import triangle as tri
from scipy import ndimage
import cv2
def guardarCSV(arreglo,nombre):
    import os
    path = os.getcwd()
    np.savetxt(path + "/"+nombre+".csv", arreglo, delimiter=",")

# %%
a = 0.3
b = 0.3
tw = 0.05
tf = 0.05

E = 200000
v = 0.27
G = E/(2*(1+v))

params = Mesh.delaunay._strdelaunay(constrained=True,delaunay=True,a='0.0005')
vertices = [[0,0],[a,0],[a,tf],[a/2+tw/2,tf],[a/2+tw/2,tf+b],[a,tf+b],[a,2*tf+b],[0,2*tf+b],[0,tf+b],[a/2-tw/2,tf+b],[a/2-tw/2,tf],[0,tf]]
geometria = Mesh.Delaunay1V(vertices, params)
zanahorias = FEM.FEM1V(geometria)
zanahorias.generarElementos()

a11 = lambda x,y: 1
a12 = lambda x,y: 0
a21 = lambda x,y: 0
a22 = lambda x,y: 1
a00 = lambda x,y: 0

theta = 1
f = lambda x,y: 2*G*theta
zanahorias.definirCondicionesDeBorde(geometria.cbe)
zanahorias.solucionar(cmap='magma',markersize=1,linewidth=1,mask=vertices,a11=a11,a12=a12,a21=a21,a22=a22,a00=a00,f=f)
# Out:
# Graficando derivada y [##################################################] 117/117

# %%
zanahorias.elementos[0].solucionInterpoladaLocal(0.15,0.3)
# Out:
# 0.0

# %%
b = 120
h = 160
E = 30*10**6
v = 0.25
geometria = Mesh.Geometria(1)
geometria.gdls = [[0,0],[b,0],[b,h],[0,h]]
geometria.tipos = ['T1V','T1V']
geometria.diccionarios = [[0,1,2],[0,2,3]]
zanahorias = FEM.Elasticidad(geometria)
zanahorias.generarElementos(gauss=5)
geometria.cbe = [[0,0],[1,0],[6,0],[7,0]]
zanahorias.F[np.ix_(np.array([2,4]))]=8000
zanahorias.definirCondicionesDeBorde(geometria.cbe)
zanahorias.solucionar(E=E,v=v,Fx=lambda x,y: 0,Fy=lambda x,y: 0,plot=False)
zanahorias.U
zanahorias.graficarSolucion(mult=100000)
plt.gca().legend(['Situacion Inicial','Deformada'])

b = 120
h = 160
E = 30*10**6
v = 0.25
geometria = Mesh.Geometria(1)
geometria.gdls = [[0,0],[b,0],[b,h],[0,h]]
geometria.tipos = ['C1V']
geometria.diccionarios = [[0,1,2,3]]
zanahorias = FEM.Elasticidad(geometria)
zanahorias.generarElementos(gauss=5)
geometria.cbe = [[0,0],[1,0],[6,0],[7,0]]
zanahorias.F[np.ix_(np.array([2,4]))]=8000
zanahorias.definirCondicionesDeBorde(geometria.cbe)
zanahorias.solucionar(E=E,v=v,Fx=lambda x,y: 0,Fy=lambda x,y: 0,plot=False)
zanahorias.U
zanahorias.graficarSolucion(mult=100000)
# Out:
# Graficando Solucion [##################################################] 1/1

# %%
fig = plt.figure()
img = cv2.imread("Untitled.png",0)
indices = np.where(img!= 255)
coordinates = [indices[0], indices[1]]
kernel = np.array([[0,1,0],[1,0,-1],[0,-1,0]])
out = np.zeros(img.shape)
ndimage.convolve(img,kernel,output=out)
plt.imshow((out > 0)+1)
img = np.copy((out > 0))

# %%
kernel = np.array([[1/9,1/9,1/9],
                   [1/9,1/9,1/9],
                   [1/9,1/9,1/9]])
x = img.shape[0]
y = img.shape[1]

offset_x = kernel.shape[0]
offset_y = kernel.shape[1]
_x = x-2*offset_x
_y = y-2*offset_y

output = np.zeros([len(range(offset_x,x-offset_x,offset_x)),len(range(offset_y,y-offset_y,offset_y))])
_i = 0
for i in range(offset_x,x-offset_x,offset_x):
    _j = 0
    for j in range(offset_y,y-offset_y,offset_y):
        kerneli = np.array([i-1,i,i+1])
        kernelj = np.array([j-1,j,j+1])
        temporal = img[np.ix_(kerneli,kernelj)]
        output[_i,_j] = np.sum(temporal@kernel)
        _j+=1
    _i+=1
img=np.copy(output)
fig = plt.figure()
plt.imshow((img > 0))
indices = np.where(img > 0)
plt.scatter(indices[1],indices[0])
vertices = [indices[0].tolist(),indices[1].tolist()]
vertices = []
for i in range(len(indices[0])):
    vertices.append([indices[0][i],indices[1][i]])

# %%
import math

pts = vertices
refvec = [0, 1]

def clockwiseangle_and_distance(point):
    # Vector between point and the origin: v = p - o
    vector = [point[0]-origin[0], point[1]-origin[1]]
    # Length of vector: ||v||
    lenvector = math.hypot(vector[0], vector[1])
    # If length is zero there is no angle
    if lenvector == 0:
        return -math.pi, 0
    # Normalize vector: v/||v||
    normalized = [vector[0]/lenvector, vector[1]/lenvector]
    dotprod  = normalized[0]*refvec[0] + normalized[1]*refvec[1]     # x1*x2 + y1*y2
    diffprod = refvec[1]*normalized[0] - refvec[0]*normalized[1]     # x1*y2 - y1*x2
    angle = math.atan2(diffprod, dotprod)
    # Negative angles represent counter-clockwise angles so we need to subtract them 
    # from 2*pi (360 degrees)
    if angle < 0:
        return 2*math.pi+angle, lenvector
    # I return first the angle because that's the primary sorting criterium
    # but if two vectors have the same angle then the shorter distance should come first.
    return angle, lenvector

# %%
fig = plt.figure()
origin = [150,70]
vertices1 = sorted(pts, key=clockwiseangle_and_distance)
params = Mesh.delaunay._strdelaunay(constrained=True,delaunay=False,q='')
plt.plot(np.array(vertices1)[:,0],np.array(vertices1)[:,1])

# %%
geometria = Mesh.Delaunay1V(vertices1, params)

# %%
fig = plt.figure()
gdls = np.array(geometria.gdls)
labels = np.linspace(0,gdls.shape[0]-1,gdls.shape[0]).astype(int)
plt.plot(gdls[:,0],gdls[:,1],'o',markersize=10,color='gray')
for p,l in zip(gdls,labels):
    plt.annotate(l,p,size=5,textcoords="offset points",xytext=(-0,-2.5),ha='center')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E = 200000
v = 0.27

zanahorias = FEM.Elasticidad(geometria)
zanahorias.generarElementos(gauss=5)
cbe0 = np.array([[904],[906],[902],[900],[899],[897],[893],[891],[889],[887],[885],[883],[881]])
cbe = np.zeros([2*cbe0.shape[0],2])
cbe[:,0]=(cbe0*2).T[0].tolist()+(cbe0*2+1).T[0].tolist()
geometria.cbe=cbe.tolist()
zanahorias.definirCondicionesDeBorde(geometria.cbe)
zanahorias.F[np.ix_(np.array([400,404,408,412,420]))]=800
zanahorias.solucionar(E=E,v=v,Fx= lambda x,y: 0,Fy = lambda x,y: 0,cmap='magma',markersize=1,linewidth=0.1,plot=False)
zanahorias.graficarSolucion(figsize=[12,7],mult=10)
plt.savefig('interesante.svg')
# Out:
# Graficando Solucion [##################################################] 6167/6167

# %%
# %matplotlib inline
#zanahorias.graficarSolucion(figsize=[12,7],mult=10)
