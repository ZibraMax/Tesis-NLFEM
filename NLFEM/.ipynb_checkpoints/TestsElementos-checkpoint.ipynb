# %%
from NLFEM import TriangularC
coords = [[0,0],[1,0],[0,1],[0.5,0],[0.5,0.5],[0,0.5]]
elemento = TriangularC(coords)
elemento.graficaJacobiano()
elemento.dibujarPsis()
# Out:
# (1.0, 1.0, 1.0)
# Substituting symbol J from STIXNonUnicode
# Substituting symbol J from STIXNonUnicode

# %%
for x,y in zip(X,Y):
    z.append(elemento.J(x,y))
# Out:
# array([[ 1.,  0.],
#        [ 0., -1.]])
